# %%
import tensorflow as tf

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Dense, MaxPooling2D, Flatten

# %%
(X_train, Y_train), (X_test, Y_test) = tf.keras.datasets.cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 1)
# (10000, 1)

# %%
X_train, X_test = X_train / 255.0, X_test / 255.0

Y_train = tf.keras.utils.to_categorical(Y_train)
Y_test = tf.keras.utils.to_categorical(Y_test)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)
# (50000, 10)
# (10000, 10)

# %%
model = Sequential()

model.add(Conv2D(32, (3,3), strides=(1,1), activation='relu', padding="SAME", input_shape=(32,32,3)))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), strides=(1,1), activation='relu', padding="SAME" ))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64, (3,3), strides=(1,1), activation='relu', padding="SAME" ))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(1024, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=10, batch_size=512 , validation_data=(X_test, Y_test))
# Out:
# Epoch 1/10
# 98/98 [==============================] - 119s 1s/step - loss: 1.7082 - accuracy: 0.3830 - val_loss: 1.4108 - val_accuracy: 0.4863
# Epoch 2/10
# 98/98 [==============================] - 125s 1s/step - loss: 1.3003 - accuracy: 0.5368 - val_loss: 1.2634 - val_accuracy: 0.5588
# Epoch 3/10
# 98/98 [==============================] - 121s 1s/step - loss: 1.1667 - accuracy: 0.5883 - val_loss: 1.0996 - val_accuracy: 0.6150
# Epoch 4/10
# 98/98 [==============================] - 127s 1s/step - loss: 1.0605 - accuracy: 0.6280 - val_loss: 1.0511 - val_accuracy: 0.6308
# Epoch 5/10
# 98/98 [==============================] - 126s 1s/step - loss: 0.9797 - accuracy: 0.6596 - val_loss: 0.9908 - val_accuracy: 0.6516
# Epoch 6/10
# 98/98 [==============================] - 124s 1s/step - loss: 0.9120 - accuracy: 0.6820 - val_loss: 0.9557 - val_accuracy: 0.6641
# Epoch 7/10
# 98/98 [==============================] - 126s 1s/step - loss: 0.8586 - accuracy: 0.7017 - val_loss: 0.9325 - val_accuracy: 0.6729
# Epoch 8/10
# 98/98 [==============================] - 124s 1s/step - loss: 0.8017 - accuracy: 0.7245 - val_loss: 0.9690 - val_accuracy: 0.6711
# Epoch 9/10
# 98/98 [==============================] - 130s 1s/step - loss: 0.7630 - accuracy: 0.7355 - val_loss: 0.8808 - val_accuracy: 0.6945
# Epoch 10/10
# 98/98 [==============================] - 124s 1s/step - loss: 0.7103 - accuracy: 0.7549 - val_loss: 0.8575 - val_accuracy: 0.7060

# %%
model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 7s 22ms/step - loss: 0.8575 - accuracy: 0.7060
# [0.8574622869491577, 0.7059999704360962]

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 1024)              1049600
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 1,116,170
# Trainable params: 1,116,170
# Non-trainable params: 0
# _________________________________________________________________
