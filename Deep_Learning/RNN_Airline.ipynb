# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('airline.csv', usecols=[1])
print(data)
df = pd.DataFrame(data)
# Out:
#      International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                                  112
# 1                                                  118
# 2                                                  132
# 3                                                  129
# 4                                                  121
# ..                                                 ...
# 139                                                606
# 140                                                508
# 141                                                461
# 142                                                390
# 143                                                432
#
# [144 rows x 1 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      International airline passengers: monthly totals in thousands. Jan 49 ? Dec 60
# 0                                                  112
# 1                                                  118
# 2                                                  132
# 3                                                  129
# 4                                                  121
# ..                                                 ...
# 139                                                606
# 140                                                508
# 141                                                461
# 142                                                390
# 143                                                432
#
# [144 rows x 1 columns]>

# %%
values = df.values.astype('float32')
values.shape
# Out:
# (144, 1)

# %%
## Splitting data for training & testing

train_size = int(values.shape[0] * 0.67)
test_size = values.shape[0] - train_size

train_data = values[0:train_size]
test_data = values[train_size:]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
sc = MinMaxScaler(feature_range = (0,1))

train_data = sc.fit_transform(train_data)
test_data = sc.transform(test_data)

# %%
print(train_data)
# Out:
# [[0.02588999]
#  [0.04530746]
#  [0.09061491]
#  [0.08090615]
#  [0.05501619]
#  [0.10032365]
#  [0.14239484]
#  [0.14239484]
#  [0.10355988]
#  [0.04854369]
#  [0.        ]
#  [0.04530746]
#  [0.03559873]
#  [0.07119742]
#  [0.11974111]
#  [0.10032365]
#  [0.06796119]
#  [0.14563107]
#  [0.21359226]
#  [0.21359226]
#  [0.17475727]
#  [0.09385115]
#  [0.03236246]
#  [0.11650488]
#  [0.13268611]
#  [0.14886734]
#  [0.2394822 ]
#  [0.1909385 ]
#  [0.22006473]
#  [0.2394822 ]
#  [0.3074434 ]
#  [0.3074434 ]
#  [0.25889972]
#  [0.18770227]
#  [0.13592234]
#  [0.20064726]
#  [0.2168285 ]
#  [0.24595472]
#  [0.2880259 ]
#  [0.24919096]
#  [0.25566342]
#  [0.36893204]
#  [0.40776703]
#  [0.44660196]
#  [0.33980587]
#  [0.28155342]
#  [0.22006473]
#  [0.29126218]
#  [0.29773465]
#  [0.29773465]
#  [0.4271845 ]
#  [0.42394826]
#  [0.4045308 ]
#  [0.4498382 ]
#  [0.5177994 ]
#  [0.54368937]
#  [0.43042073]
#  [0.34627834]
#  [0.24595472]
#  [0.31391588]
#  [0.32362464]
#  [0.27184466]
#  [0.42394826]
#  [0.39805827]
#  [0.42071202]
#  [0.5177994 ]
#  [0.64077675]
#  [0.61165047]
#  [0.50161815]
#  [0.4045308 ]
#  [0.32038835]
#  [0.4045308 ]
#  [0.44660196]
#  [0.41747573]
#  [0.52750814]
#  [0.5339806 ]
#  [0.5372169 ]
#  [0.682848  ]
#  [0.841424  ]
#  [0.7864078 ]
#  [0.6731392 ]
#  [0.55016184]
#  [0.43042073]
#  [0.5631068 ]
#  [0.5825243 ]
#  [0.5598706 ]
#  [0.68932045]
#  [0.6763755 ]
#  [0.69255674]
#  [0.87378645]
#  [1.0000001 ]
#  [0.9741101 ]
#  [0.8122978 ]
#  [0.6537217 ]
#  [0.5404531 ]
#  [0.6537217 ]]

# %%
def create_dataset(data, k):
  dataX, dataY = [],[]
  for i in range(len(data)- k):
    x = data[i:i+k, 0]
    y = data[i+k, 0]
    dataX.append(x)
    dataY.append(y)
  return np.array(dataX), np.array(dataY)

# %%
look_back = 12
X_train, Y_train = create_dataset(train_data, look_back)
X_test, Y_test = create_dataset(test_data, look_back)

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (84, 12)
# (84,)
# (36, 12)
# (36,)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (84, 12, 1)
# (84,)
# (36, 12, 1)
# (36,)

# %%
## Building model
import tensorflow
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(32, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error', metrics = ['accuracy'])
model.fit(X_train, Y_train, epochs=10, batch_size=1)
# Out:
# Epoch 1/10
# 84/84 [==============================] - 2s 4ms/step - loss: 0.0145 - accuracy: 0.0000e+00
# Epoch 2/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0050 - accuracy: 0.0000e+00
# Epoch 3/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0049 - accuracy: 0.0000e+00
# Epoch 4/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0045 - accuracy: 0.0000e+00
# Epoch 5/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0041 - accuracy: 0.0000e+00
# Epoch 6/10
# 84/84 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.0000e+00
# Epoch 7/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0037 - accuracy: 0.0000e+00
# Epoch 8/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0031 - accuracy: 0.0000e+00
# Epoch 9/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0029 - accuracy: 0.0000e+00
# Epoch 10/10
# 84/84 [==============================] - 0s 3ms/step - loss: 0.0026 - accuracy: 0.0000e+00

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 32)                1088
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 1,121
# Trainable params: 1,121
# Non-trainable params: 0
# _________________________________________________________________
